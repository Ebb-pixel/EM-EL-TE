# %%
# Install MMDetection
# !git clone https://github.com/open-mmlab/mmdetection.git
# Out:
# Cloning into 'mmdetection'...
# remote: Enumerating objects: 38023, done.
# remote: Total 38023 (delta 0), reused 0 (delta 0), pack-reused 38023 (from 1)
# Receiving objects: 100% (38023/38023), 63.18 MiB | 18.82 MiB/s, done.
# Resolving deltas: 100% (26221/26221), done.

# %%
# %cd mmdetection
# Out:
# /content/mmdetection

# %%
# !pip install -r requirements/build.txt

# %%
# !pip install -v -e .
# Out:
# Using pip 24.1.2 from /usr/local/lib/python3.11/dist-packages/pip (python 3.11)
# Obtaining file:///content/mmdetection
#   Running command python setup.py egg_info
#   No CUDA runtime is found, using CUDA_HOME='/usr/local/cuda'
#   running egg_info
#   creating /tmp/pip-pip-egg-info-akvqxf_z/mmdet.egg-info
#   writing /tmp/pip-pip-egg-info-akvqxf_z/mmdet.egg-info/PKG-INFO
#   writing dependency_links to /tmp/pip-pip-egg-info-akvqxf_z/mmdet.egg-info/dependency_links.txt
#   writing requirements to /tmp/pip-pip-egg-info-akvqxf_z/mmdet.egg-info/requires.txt
#   writing top-level names to /tmp/pip-pip-egg-info-akvqxf_z/mmdet.egg-info/top_level.txt
#   writing manifest file '/tmp/pip-pip-egg-info-akvqxf_z/mmdet.egg-info/SOURCES.txt'
#   reading manifest file '/tmp/pip-pip-egg-info-akvqxf_z/mmdet.egg-info/SOURCES.txt'
#   reading manifest template 'MANIFEST.in'
# ...
#   adding license file 'LICENSE'
#   writing manifest file '/tmp/pip-pip-egg-info-akvqxf_z/mmdet.egg-info/SOURCES.txt'
# ...

# %%
# %cd /content
# Out:
# /content

# %%
# !git clone https://github.com/open-mmlab/mmpose.git
# Out:
# Cloning into 'mmpose'...
# remote: Enumerating objects: 31261, done.
# remote: Counting objects: 100% (176/176), done.
# remote: Compressing objects: 100% (103/103), done.
# remote: Total 31261 (delta 119), reused 73 (delta 73), pack-reused 31085 (from 2)
# Receiving objects: 100% (31261/31261), 53.49 MiB | 28.50 MiB/s, done.
# Resolving deltas: 100% (22000/22000), done.

# %%
# %cd mmpose
# Out:
# /content/mmpose

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.6/50.6 kB 3.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.8/46.8 kB 3.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.3/42.3 kB 3.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 109.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 56.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 40.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.2 MB/s eta 0:00:00
# ...

# %%
# !pip install -v -e
# Out:
# Usage:
#   pip3 install [options] <requirement specifier> [package-index-options] ...
#   pip3 install [options] -r <requirements file> [package-index-options] ...
#   pip3 install [options] [-e] <vcs project url> ...
#   pip3 install [options] [-e] <local project path> ...
#   pip3 install [options] <archive url/path> ...
#
# -e option requires 1 argument

# %%
# %cd /content/mmdetection
# Out:
# /content/mmdetection

# %%
# !ls configs/faster_rcnn/
# Out:
# faster-rcnn_r101-caffe_fpn_1x_coco.py
# faster-rcnn_r101-caffe_fpn_ms-3x_coco.py
# faster-rcnn_r101_fpn_1x_coco.py
# faster-rcnn_r101_fpn_2x_coco.py
# faster-rcnn_r101_fpn_8xb8-amp-lsj-200e_coco.py
# faster-rcnn_r101_fpn_ms-3x_coco.py
# faster-rcnn_r18_fpn_8xb8-amp-lsj-200e_coco.py
# faster-rcnn_r50-caffe_c4-1x_coco.py
# faster-rcnn_r50-caffe-c4_ms-1x_coco.py
# faster-rcnn_r50-caffe-dc5_1x_coco.py
# faster-rcnn_r50-caffe-dc5_ms-1x_coco.py
# faster-rcnn_r50-caffe-dc5_ms-3x_coco.py
# faster-rcnn_r50-caffe_fpn_1x_coco.py
# faster-rcnn_r50-caffe_fpn_90k_coco.py
# faster-rcnn_r50-caffe_fpn_ms-1x_coco-person-bicycle-car.py
# faster-rcnn_r50-caffe_fpn_ms-1x_coco-person.py
# faster-rcnn_r50-caffe_fpn_ms-1x_coco.py
# faster-rcnn_r50-caffe_fpn_ms-2x_coco.py
# faster-rcnn_r50-caffe_fpn_ms-3x_coco.py
# faster-rcnn_r50-caffe_fpn_ms-90k_coco.py
# faster-rcnn_r50_fpn_1x_coco.py
# faster-rcnn_r50_fpn_2x_coco.py
# faster-rcnn_r50_fpn_8xb8-amp-lsj-200e_coco.py
# faster-rcnn_r50_fpn_amp-1x_coco.py
# ...

# %%
# !cp configs/faster_rcnn/faster-rcnn_r50_fpn_1x_coco.py configs/faster_rcnn/custom_underwater.py

# %%
# ✅ Full editable config for your underwater person detector
config_text = """
_base_ = [
    '../_base_/models/faster-rcnn_r50_fpn.py',
    '../_base_/datasets/coco_detection.py',
    '../_base_/schedules/schedule_1x.py',
    '../_base_/default_runtime.py'
]

model = dict(
    roi_head=dict(
        bbox_head=dict(num_classes=1)
    )
)

classes = ('person',)
data_root = 'data/underwater/'

data = dict(
    train=dict(
        img_prefix=data_root + 'train/',
        classes=classes,
        ann_file=data_root + 'annotations/instances_train.json'
    ),
    val=dict(
        img_prefix=data_root + 'val/',
        classes=classes,
        ann_file=data_root + 'annotations/instances_val.json'
    ),
    test=dict(
        img_prefix=data_root + 'val/',
        classes=classes,
        ann_file=data_root + 'annotations/instances_val.json'
    )
)

load_from = 'checkpoints/faster_rcnn_r50_fpn_1x_coco.pth'
work_dir = './work_dirs/custom_underwater'
"""

# 🔄 Save this config, overwriting the original with write permissions
with open('/content/mmdetection/configs/faster_rcnn/custom_underwater.py', 'w') as f:
    f.write(config_text)

print("✅ custom_underwater.py updated and now editable.")
# Out:
# ✅ custom_underwater.py updated and now editable.

# %%
# !mkdir -p checkpoints
# !wget https://download.openmmlab.com/mmdetection/v2.0/faster_rcnn/faster_rcnn_r50_fpn_1x_coco_20200130-047c8118.pth \
     -O checkpoints/faster_rcnn_r50_fpn_1x_coco.pth
# Out:
# --2025-07-09 12:39:39--  https://download.openmmlab.com/mmdetection/v2.0/faster_rcnn/faster_rcnn_r50_fpn_1x_coco_20200130-047c8118.pth
# Resolving download.openmmlab.com (download.openmmlab.com)... 47.246.48.187, 47.246.48.186, 47.246.48.190, ...
# Connecting to download.openmmlab.com (download.openmmlab.com)|47.246.48.187|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2025-07-09 12:39:41 ERROR 404: Not Found.
